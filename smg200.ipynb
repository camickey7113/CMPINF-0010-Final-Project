# %% [markdown]
# # SubMetric : Availablity of playing field in neighborhood

# %% [markdown]
# # Introduction
# The submetric I am using to determine the best neighnorhood in terms of raising children is availability of playing fields in neighboor hood in pittsburgh.

# %% [markdown]
# # Data and Analysis

# %%
import pandas as pd

# %%
import pandas as pd
parks = pd.read_csv("playing fields.csv")
parks.head()
# Out:
#            id               name has_lights                    park  \
# 0  1914615260  Arlington Field 1          t          Arlington Park
# 1  1151740179          Armstrong          f          Armstrong Park
# 2   971009139            Bandbox          f            Arsenal Park
# 3  1581124728         Banksville          f         Banksville Park
# 4  1052125703  Banksville School          t  Banksville School Park
#
#                field_usage  goal_post infield_type  left_field_distance  \
# 0             Diamond Only          0      Skinned                160.0
# 1  Diamond and Rectangular          0      Skinned                240.0
# 2             Diamond Only          0      Skinned                135.0
# 3             Diamond Only          0      Skinned                304.0
# 4             Diamond Only          0      Skinned                180.0
#
#    center_field_distance  right_field_distance  ...         neighborhood  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.close("all")
df= pd.read_csv("playing fields.csv")
df
# Out:
#              id                  name has_lights  \
# 0    1914615260     Arlington Field 1          t
# 1    1151740179             Armstrong          f
# 2     971009139               Bandbox          f
# 3    1581124728            Banksville          f
# 4    1052125703     Banksville School          t
# ..          ...                   ...        ...
# 109    88488317      Westwood Field 2          t
# 110  1139931087              Wightman          f
# 111   916748391       Willie Stargell          t
# 112  2031862261               Winters          f
# 113  2136373152  Olympia Soccer Field          t
#
#                                  park              field_usage  goal_post  \
# 0                      Arlington Park             Diamond Only          0
# 1                      Armstrong Park  Diamond and Rectangular          0
# 2                        Arsenal Park             Diamond Only          0
# 3                     Banksville Park             Diamond Only          0
# ...

# %%
import pandas as pd

df= pd.read_csv("playing fields.csv")
num_count=df['neighborhood'].value_counts()
print(num_count)
# Out:
# Brighton Heights            7
# South Side Slopes           6
# Brookline                   6
# Squirrel Hill South         5
# Carrick                     5
# Lower Lawrenceville         4
# Mount Washington            4
# Hazelwood                   4
# Highland Park               4
# Sheraden                    3
# Shadyside                   3
# Troy Hill                   3
# Morningside                 3
# Beechview                   3
# Beltzhoover                 3
# Central Lawrenceville       2
# Bedford Dwellings           2
# Allegheny Center            2
# Greenfield                  2
# Manchester                  2
# Perry North                 2
# Spring Hill-City View       2
# Westwood                    2
# South Side Flats            2
# Elliott                     2
# South Oakland               2
# Regent Square               2
# Banksville                  2
# Crafton Heights             2
# Lincoln-Lemington-Belmar    2
# Windgap                     1
# ...

# %%
num_count=df['neighborhood'].value_counts()
plt.figure(figsize=(10,5))
num_count.plot(kind='bar')

plt.xlabel('neighborhood')
plt.ylabel('number of playing fields')
plt.title('playing fields by neighborhood')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df= pd.read_csv("playing fields.csv")

num_count=df['neighborhood'].value_counts()
plt.figure(figsize=(10,5))
num_count.plot()

plt.xlabel('neighborhood')
plt.ylabel('number of playing fields')
plt.title('playing fields by neighborhood')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df= pd.read_csv("playing fields.csv")

count=df['field_usage'].unique()
print(count)
# Out:
# ['Diamond Only' 'Diamond and Rectangular' 'Rectangular Only']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df= pd.read_csv("playing fields.csv")

filtered_df=df[df['field_usage'].str.contains('Diamond and Rectangular')]
print(filtered_df['neighborhood'].unique())
# Out:
# ['South Side Flats' 'Brookline' 'Elliott' 'Highland Park' 'Morningside'
#  'Central Lawrenceville' 'Terrace Village' 'Beltzhoover'
#  'Allegheny Center' 'Sheraden' 'West End' 'Polish Hill' 'Westwood'
#  'Homewood South']

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("playing fields.csv")

grouped = df.groupby(['neighborhood', 'field_usage'])['field_usage'].count().unstack('field_usage').fillna(0)
plt.figure(figsize=(30,12))
grouped.plot(kind='bar', stacked=True)

plt.xlabel('neighborhood')
plt.ylabel('count')
plt.title('playing fields by neighborhood and type of usage')
plt.show()

# %% [markdown]
# # Conclusion
# According to the metric used, the availability of playing fields, Brookline is the best because it has a disproportionately large number of playing fields and because, in contrast to the others, its playing fields are utilized for several sports, including football, baseball, and soccer.
